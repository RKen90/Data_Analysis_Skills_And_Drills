# %% [markdown]
# Skills for today
# 1. **Loading Data** (Pandas Analysis):
#    - **Task**: Load a dataset in CSV format into a Pandas DataFrame using `pd.read_csv()`. This is foundational for any further analysis or visualization.
#
#
# 2. **Basic Data Inspection** (Pandas Analysis):
#    - **Task**: Inspect the first few rows and check the structure of the dataset using `.head()`, `.info()`, and `.describe()`.
#
#
# 3. **Basic Line Plot** (Visualization):
#    - **Task**: Create a simple line plot using the dataset, visualizing any numerical trend over time or sequential data using `df.plot(kind='line')`.

# %% [markdown]
# Task 1
# 1. **Loading Data** (Pandas Analysis):
#    - **Task**: Load a dataset in CSV format into a Pandas DataFrame using `pd.read_csv()`. This is foundational for any further analysis or visualization.

# %%
import pandas as pd

# %%
egypt = pd.read_csv("archive (12)/gldv2_info.csv")
egypt
# Out:
#               gldv2_id                                                url  \
# 0     a2c2490adcd9361d  https://upload.wikimedia.org/wikipedia/commons...
# 1     a38c385bf41aaff3  https://upload.wikimedia.org/wikipedia/commons...
# 2     790ac011ae5178ec  https://upload.wikimedia.org/wikipedia/commons...
# 3     8d11015559f719c9  https://upload.wikimedia.org/wikipedia/commons...
# 4     330cb83786026637  https://upload.wikimedia.org/wikipedia/commons...
# ...                ...                                                ...
# 5409  447919f385700289  https://upload.wikimedia.org/wikipedia/commons...
# 5410  af09233fc1cb37f2  https://upload.wikimedia.org/wikipedia/commons...
# 5411  53c08b9a7f2e433e  http://upload.wikimedia.org/wikipedia/commons/...
# 5412  9dbbe0fd2a3a8404  http://upload.wikimedia.org/wikipedia/commons/...
# 5413  7159129774f082be  https://upload.wikimedia.org/wikipedia/commons...
#
#       landmark_id                        name
# ...

# %%
wuzzuf = pd.read_csv("Wuzzuf_Jobs.csv")
wuzzuf
# Out:
#                                                Title  \
# 0                             Customer Service Agent
# 1                                  Marketing Manager
# 2                  Medical Representative Heliopolis
# 3                          Order Handling Specialist
# 4                                        Storekeeper
# ...                                              ...
# 4375      Corporate Sales Executive - Hotel Supplies
# 4376     Logistics Operations & Warehouse Supervisor
# 4377  English Teacher ( Second Language ) / Lower...
# 4378                         Project Manager - Cairo
# 4379                English Teacher / Primary Stages
#
#                                    Company     Location       Type  \
# 0                         Johnson Controls    New Cairo  Full Time
# 1                    SYE English Community        Dokki  Full Time
# 2                          So Value Pharma        Cairo  Full Time
# ...

# %%
student_performance = pd.read_csv("student_performance.csv")
student_performance
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male              85                 15
# 1          2     Sarah  Female              90                 20
# 2          3      Alex    Male              78                 10
# 3          4   Michael    Male              92                 25
# 4          5      Emma  Female              88                 18
# 5          6    Olivia  Female              95                 30
# 6          7    Daniel    Male              70                  8
# 7          8    Sophia  Female              85                 17
# 8          9     James    Male              82                 12
# 9         10  Isabella  Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# 1             85                          2          Medium          87
# ...

# %% [markdown]
# 2. **Basic Data Inspection** (Pandas Analysis):
#    - **Task**: Inspect the first few rows and check the structure of the dataset using `.head()`, `.info()`, and `.describe()`.

# %%
egypt.head(10)
# Out:
#            gldv2_id                                                url  \
# 0  a2c2490adcd9361d  https://upload.wikimedia.org/wikipedia/commons...
# 1  a38c385bf41aaff3  https://upload.wikimedia.org/wikipedia/commons...
# 2  790ac011ae5178ec  https://upload.wikimedia.org/wikipedia/commons...
# 3  8d11015559f719c9  https://upload.wikimedia.org/wikipedia/commons...
# 4  330cb83786026637  https://upload.wikimedia.org/wikipedia/commons...
# 5  93385722c6155609  https://upload.wikimedia.org/wikipedia/commons...
# 6  f50a10f1e28df7c3  https://upload.wikimedia.org/wikipedia/commons...
# 7  085c0bfbe60cd5df  https://upload.wikimedia.org/wikipedia/commons...
# 8  d30673fab6a62988  https://upload.wikimedia.org/wikipedia/commons...
# 9  51649134e1faaafd  https://upload.wikimedia.org/wikipedia/commons...
#
#    landmark_id                 name
# 0      89384.0  Bab_al-Nasr_(Cairo)
# 1      89384.0  Bab_al-Nasr_(Cairo)
# 2      89384.0  Bab_al-Nasr_(Cairo)
# 3      89384.0  Bab_al-Nasr_(Cairo)
# ...

# %%
egypt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5414 entries, 0 to 5413
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gldv2_id     5414 non-null   object
#  1   url          5414 non-null   object
#  2   landmark_id  5414 non-null   float64
#  3   name         5414 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 169.3+ KB

# %%
egypt.describe()
# Out:
#          landmark_id
# count    5414.000000
# mean   108167.296269
# std     59977.026791
# min       125.000000
# 25%     56733.000000
# 50%    107673.000000
# 75%    160379.000000
# max    202118.000000

# %%
wuzzuf
# Out:
#                                                Title  \
# 0                             Customer Service Agent
# 1                                  Marketing Manager
# 2                  Medical Representative Heliopolis
# 3                          Order Handling Specialist
# 4                                        Storekeeper
# ...                                              ...
# 4375      Corporate Sales Executive - Hotel Supplies
# 4376     Logistics Operations & Warehouse Supervisor
# 4377  English Teacher ( Second Language ) / Lower...
# 4378                         Project Manager - Cairo
# 4379                English Teacher / Primary Stages
#
#                                    Company     Location       Type  \
# 0                         Johnson Controls    New Cairo  Full Time
# 1                    SYE English Community        Dokki  Full Time
# 2                          So Value Pharma        Cairo  Full Time
# ...

# %%
wuzzuf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4380 entries, 0 to 4379
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     4380 non-null   object
#  1   Company   4380 non-null   object
#  2   Location  4380 non-null   object
#  3   Type      4380 non-null   object
#  4   Level     4380 non-null   object
#  5   YearsExp  4380 non-null   object
#  6   Country   4380 non-null   object
#  7   Skills    4380 non-null   object
# dtypes: object(8)
# memory usage: 273.9+ KB

# %% [markdown]
# When you use `.info()` on a DataFrame, you're getting a **summary** of the dataset, which helps you quickly understand its structure and content. Here’s what to look for:
#
# ### Key Things to Look for in `.info()` Output:
#
# 1. **Total Number of Entries**:
#    - The range at the top shows how many rows the DataFrame has. In your case, the range is from 0 to 4379, indicating there are 4380 entries.
#    - This helps you confirm the dataset's size.
#
# 2. **Number of Columns and Their Names**:
#    - It lists all the column names and their respective data types.
#    - In your case, the columns are: `Title`, `Company`, `Location`, `Type`, `Level`, `YearsExp`, `Country`, and `Skills`.
#
# 3. **Non-null Count**:
#    - For each column, it shows how many non-null (non-missing) values exist.
#    - If a column has missing data, the count of non-null values will be less than the total number of entries.
#    - In your dataset, all columns have 4380 non-null entries, meaning there are **no missing values**.
#
# 4. **Data Types**:
#    - `.info()` shows the data types of each column (e.g., object, int64, float64).
#    - All columns in your dataset are of type `object`, which typically means they contain text or categorical data (not numerical).
#    - If you expected some columns (e.g., `YearsExp`) to be numerical, this would be a flag that those columns need conversion or cleaning.
#
# ### Insights You Can Get:
# - **Missing Data**: If any column has fewer non-null values than the total number of rows, you may need to address missing data.
# - **Data Types**: Check if the data types match your expectations. For example, you might want `YearsExp` to be numeric, but it’s currently an `object`. You may need to convert or clean this column.
# - **Data Readiness**: This gives you an idea of whether the data is in a state ready for analysis (e.g., no missing values, correct data types) or if it needs further cleaning.

# %%
wuzzuf.describe()
# Out:
#              Title       Company Location       Type        Level  \
# count         4380          4380     4380       4380         4380
# unique        2965          1534      162          6            9
# top     Accountant  Confidential    Cairo  Full Time  Experienced
# freq            57           590      563       4168         2198
#
#               YearsExp Country  \
# count             4380    4380
# unique             101      42
# top     1-3 Yrs of Exp   Cairo
# freq               414    2230
#
#                                                    Skills
# count                                                4380
# unique                                               4227
# top     Corporate Sales, Real Estate, Advertising, Mar...
# freq                                                   12

# %% [markdown]
# When you use `.describe()` on a DataFrame, it provides a summary of statistics for each column. By default, `.describe()` is most useful for **numerical columns**, but in this case, your data is all of type `object` (text or categorical). For **categorical data**, `.describe()` focuses on **count, unique, top, and frequency**.
#
# Here’s what each statistic represents and how to interpret them for your dataset:
#
# ### Key Outputs of `.describe()` for Categorical Data:
#
# 1. **Count**:
#    - The total number of non-null (non-missing) entries in each column.
#    - For all columns in your dataset, the count is 4380, meaning there are no missing values.
#
# 2. **Unique**:
#    - The number of **unique** values in each column.
#    - For example, the `Title` column has 2965 unique job titles, while the `Company` column has 1534 unique companies.
#    - This gives an idea of how varied the entries are in each column.
#
# 3. **Top**:
#    - The **most frequent value** (mode) in each column.
#    - For example, in the `Title` column, "Accountant" is the most frequent job title.
#    - In `Company`, the most frequent value is "Confidential" (probably anonymized data).
#
# 4. **Freq**:
#    - The **frequency** of the top value.
#    - For example, "Accountant" appears 57 times in the `Title` column, and "Confidential" appears 590 times in the `Company` column.
#
# ### Insights from `.describe()`:
# - **Job Variety**: There are 2965 unique job titles, which indicates a diverse range of jobs.
# - **Company Representation**: 1534 unique companies, but the most frequent company ("Confidential") appears 590 times, suggesting that a significant portion of job listings may not reveal the company name.
# - **Location Variety**: Cairo appears the most (563 times), which could indicate the dataset is regionally focused on Cairo.
# - **Employment Type**: "Full Time" is overwhelmingly the most common employment type (4168 out of 4380 entries).
# - **Experience Level**: The "Experienced" level is the most common, with 2198 entries, meaning over half of the job listings are targeted at people with experience.
#
# ### Why `.describe()` is Useful:
# - **Get a Quick Overview**: You can quickly see which values are the most common, how diverse the entries are in each column, and identify columns with potential issues (e.g., too many "Confidential" entries).
# - **Check for Data Imbalance**: For example, if you’re analyzing experience levels, seeing that "Experienced" dominates could suggest an imbalance in the data that might affect conclusions.
# - **Spotting Repetition or Anonymization**: For example, the high frequency of "Confidential" in the company column suggests that many job postings might not be revealing the employer’s identity.
#
# Would you like to analyze or visualize any specific parts of this dataset, or should we explore a new direction?

# %%
student_performance
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male              85                 15
# 1          2     Sarah  Female              90                 20
# 2          3      Alex    Male              78                 10
# 3          4   Michael    Male              92                 25
# 4          5      Emma  Female              88                 18
# 5          6    Olivia  Female              95                 30
# 6          7    Daniel    Male              70                  8
# 7          8    Sophia  Female              85                 17
# 8          9     James    Male              82                 12
# 9         10  Isabella  Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# 1             85                          2          Medium          87
# ...

# %%
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10 non-null     int64
#  1   Name                       10 non-null     object
#  2   Gender                     10 non-null     object
#  3   AttendanceRate             10 non-null     int64
#  4   StudyHoursPerWeek          10 non-null     int64
#  5   PreviousGrade              10 non-null     int64
#  6   ExtracurricularActivities  10 non-null     int64
#  7   ParentalSupport            10 non-null     object
#  8   FinalGrade                 10 non-null     int64
# dtypes: int64(6), object(3)
# memory usage: 852.0+ bytes

# %%
student_performance.describe()
# Out:
#        StudentID  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# count   10.00000       10.000000          10.000000      10.000000
# mean     5.50000       85.600000          17.700000      78.100000
# std      3.02765        7.441625           6.848357      10.170218
# min      1.00000       70.000000           8.000000      60.000000
# 25%      3.25000       82.750000          12.750000      71.750000
# 50%      5.50000       86.500000          17.500000      80.000000
# 75%      7.75000       90.750000          21.500000      85.750000
# max     10.00000       95.000000          30.000000      90.000000
#
#        ExtracurricularActivities  FinalGrade
# count                  10.000000   10.000000
# mean                    1.500000   80.200000
# std                     1.080123   10.097304
# min                     0.000000   62.000000
# 25%                     1.000000   73.500000
# 50%                     1.500000   82.500000
# ...

# %% [markdown]
# The `.describe()` output you've provided contains **summary statistics** for a numerical dataset with columns like **Attendance Rate**, **Study Hours per Week**, **Previous Grade**, **Extracurricular Activities**, and **Final Grade**. Let’s break down what we can learn from each statistic:
#
# ### Key Statistics in `.describe()` for Numerical Data:
#
# 1. **Count**:
#    - This tells us the number of non-null entries for each column. In this case, all columns have 10 entries, meaning there are no missing values.
#
# 2. **Mean** (Average):
#    - **AttendanceRate**: The average attendance rate is 85.6%.
#    - **StudyHoursPerWeek**: Students, on average, study 17.7 hours per week.
#    - **PreviousGrade**: The average previous grade of the students is 78.1.
#    - **ExtracurricularActivities**: On average, students participate in 1.5 extracurricular activities (likely indicating a count of activities).
#    - **FinalGrade**: The average final grade is 80.2.
#
# 3. **Standard Deviation (std)**:
#    - Measures the spread of the data around the mean. A higher standard deviation means more variability.
#    - **StudyHoursPerWeek**: 6.85 indicates there's some variability in how much students study.
#    - **ExtracurricularActivities**: 1.08 shows some students are involved in multiple extracurriculars, while others may not be.
#    - **FinalGrade**: 10.1 suggests a moderate spread of final grades among students.
#
# 4. **Minimum (min)**:
#    - The lowest value in each column.
#    - The lowest **AttendanceRate** is 70%, the lowest **FinalGrade** is 62, and one student participates in 0 extracurricular activities.
#
# 5. **25th Percentile (25%)**:
#    - The first quartile, meaning 25% of the students have values **below** this number.
#    - **AttendanceRate**: 82.75% indicates that the bottom 25% of students attend class less often than the others.
#    - **StudyHoursPerWeek**: 12.75 hours, showing a quarter of students study less than this each week.
#    - **FinalGrade**: 73.5, showing that a quarter of students scored below this mark.
#
# 6. **50th Percentile (50% or Median)**:
#    - The middle value of the dataset (half the values are below this, half are above).
#    - **AttendanceRate**: 86.5% means half the students attend classes more than 86.5% of the time.
#    - **StudyHoursPerWeek**: 17.5 hours is the median study time.
#    - **FinalGrade**: The median final grade is 82.5, showing that half the students scored above and half scored below this grade.
#
# 7. **75th Percentile (75%)**:
#    - The third quartile, meaning 25% of students have values **above** this number.
#    - **AttendanceRate**: 90.75% means a quarter of the students attend class more than 90.75% of the time.
#    - **StudyHoursPerWeek**: 21.5 hours, so 25% of students study more than this per week.
#    - **FinalGrade**: 87.75, meaning a quarter of students scored higher than this.
#
# 8. **Maximum (max)**:
#    - The highest value in each column.
#    - **AttendanceRate**: The highest attendance rate is 95%.
#    - **FinalGrade**: The highest final grade is 92.
#
# ### Insights You Can Learn:
#
# 1. **Attendance and Grades**: Students have a relatively high attendance rate (mean of 85.6%) and correspondingly high grades (mean final grade of 80.2), with some variation (std of about 10 for both).
#
# 2. **Study Habits**: Study hours per week vary quite a bit (from 8 to 30 hours, with a std of 6.8). The median study time is 17.5 hours per week, but the upper quartile is studying significantly more (over 21.5 hours).
#
# 3. **Extracurricular Participation**: Participation in extracurricular activities ranges from 0 to 3, with most students engaging in 1 to 2 activities.
#
# 4. **Grade Distribution**: Final grades have a relatively narrow spread (between 62 and 92), and the distribution is fairly balanced, with the median grade being 82.5. This suggests that most students are performing well.
#
# ### What to Focus On:
# - **Correlation between variables**: You could explore how **Study Hours** or **Attendance Rate** correlate with **Final Grade**. For example, do students who study more or attend class more frequently have higher final grades?
# - **Extracurricular Activities**: Look into whether extracurricular participation has any impact on grades.
# - **Grade Spread**: While the grades are fairly high, there's enough variation to analyze what could be driving the differences (e.g., study habits, attendance).
#
# Would you like to visualize some of these relationships or dive deeper into any specific analysis?

# %% [markdown]
# 3. **Basic Line Plot** (Visualization):
#    - **Task**: Create a simple line plot using the dataset, visualizing any numerical trend over time or sequential data using `df.plot(kind='line')`.

# %%
wuzzuf
# Out:
#                                                Title  \
# 0                             Customer Service Agent
# 1                                  Marketing Manager
# 2                  Medical Representative Heliopolis
# 3                          Order Handling Specialist
# 4                                        Storekeeper
# ...                                              ...
# 4375      Corporate Sales Executive - Hotel Supplies
# 4376     Logistics Operations & Warehouse Supervisor
# 4377  English Teacher ( Second Language ) / Lower...
# 4378                         Project Manager - Cairo
# 4379                English Teacher / Primary Stages
#
#                                    Company     Location       Type  \
# 0                         Johnson Controls    New Cairo  Full Time
# 1                    SYE English Community        Dokki  Full Time
# 2                          So Value Pharma        Cairo  Full Time
# ...

# %%
wuzzuf['Location'].value_counts().head(10)
# Out:
# Location
#  Cairo             563
#  Maadi             525
#  New Cairo         522
#  Nasr City         424
#  6th of October    282
#  Heliopolis        247
#  Mohandessin       140
#  Dokki             140
#  Alexandria        130
#  Giza              126
# Name: count, dtype: int64

# %%
wuzzuf['Location'].value_counts().head(10).plot(kind = "bar", title = "Location Frequency")
# Out:
# <Axes: title={'center': 'Location Frequency'}, xlabel='Location'>

# %%
wuzzuf['Location'].value_counts().plot(kind='bar', figsize=(10,6), title="Location Frequency")
plt.xticks(rotation=90)  # Rotate x-axis labels to avoid overlap
plt.ylabel('Frequency')  # Label for the y-axis
plt.tight_layout()       # Adjust layout to ensure everything fits well
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 wuzzuf['Location'].value_counts().plot(kind='bar', figsize=(10,6), title="Location Frequency")
# ----> 2 plt.xticks(rotation=90)  # Rotate x-axis labels to avoid overlap
#       3 plt.ylabel('Frequency')  # Label for the y-axis
#       4 plt.tight_layout()       # Adjust layout to ensure everything fits well
#
# NameError: name 'plt' is not defined

# %%
wuzzuf[]

# %%
student_performance
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male              85                 15
# 1          2     Sarah  Female              90                 20
# 2          3      Alex    Male              78                 10
# 3          4   Michael    Male              92                 25
# 4          5      Emma  Female              88                 18
# 5          6    Olivia  Female              95                 30
# 6          7    Daniel    Male              70                  8
# 7          8    Sophia  Female              85                 17
# 8          9     James    Male              82                 12
# 9         10  Isabella  Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# 1             85                          2          Medium          87
# ...

# %%
student_performance.plot.scatter(x='AttendanceRate', y='FinalGrade', figsize=(8,6), title='Attendance Rate vs Final Grade')
# Out:
# <Axes: title={'center': 'Attendance Rate vs Final Grade'}, xlabel='AttendanceRate', ylabel='FinalGrade'>

# %%
student_performance.plot.scatter(x='StudyHoursPerWeek', y='FinalGrade', figsize=(8,6), title='Study Hours per Week vs Final Grade')
# Out:
# <Axes: title={'center': 'Study Hours per Week vs Final Grade'}, xlabel='StudyHoursPerWeek', ylabel='FinalGrade'>

# %%
student_performance['Gender'].value_counts().plot(kind='bar', figsize=(8,6), title='Gender Distribution')
# Out:
# <Axes: title={'center': 'Gender Distribution'}, xlabel='Gender'>

# %%
student_performance.groupby('ExtracurricularActivities')['FinalGrade'].mean().plot(kind='bar', figsize=(8,6), title='Extracurricular Activities vs Final Grade')
# Out:
# <Axes: title={'center': 'Extracurricular Activities vs Final Grade'}, xlabel='ExtracurricularActivities'>

# %%
student_performance.boxplot(column='FinalGrade', by='ParentalSupport', figsize=(8,6))
plt.title('Parental Support vs Final Grade')
plt.suptitle('')  # This removes the default 'Boxplot grouped by' title.
plt.xlabel('Parental Support')
plt.ylabel('Final Grade')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 student_performance.boxplot(column='FinalGrade', by='ParentalSupport', figsize=(8,6))
# ----> 2 plt.title('Parental Support vs Final Grade')
#       3 plt.suptitle('')  # This removes the default 'Boxplot grouped by' title.
#       4 plt.xlabel('Parental Support')
#
# NameError: name 'plt' is not defined

# %%
egypt
# Out:
#               gldv2_id                                                url  \
# 0     a2c2490adcd9361d  https://upload.wikimedia.org/wikipedia/commons...
# 1     a38c385bf41aaff3  https://upload.wikimedia.org/wikipedia/commons...
# 2     790ac011ae5178ec  https://upload.wikimedia.org/wikipedia/commons...
# 3     8d11015559f719c9  https://upload.wikimedia.org/wikipedia/commons...
# 4     330cb83786026637  https://upload.wikimedia.org/wikipedia/commons...
# ...                ...                                                ...
# 5409  447919f385700289  https://upload.wikimedia.org/wikipedia/commons...
# 5410  af09233fc1cb37f2  https://upload.wikimedia.org/wikipedia/commons...
# 5411  53c08b9a7f2e433e  http://upload.wikimedia.org/wikipedia/commons/...
# 5412  9dbbe0fd2a3a8404  http://upload.wikimedia.org/wikipedia/commons/...
# 5413  7159129774f082be  https://upload.wikimedia.org/wikipedia/commons...
#
#       landmark_id                        name
# ...

# %%
# Selecting the unique locations from the 'name' and 'landmark_id' columns
unique_locations = egypt[['landmark_id', 'name']].drop_duplicates()

# Display the first few unique landmark names and their associated IDs
unique_locations.head()
# Out:
#     landmark_id                                name
# 0       89384.0                 Bab_al-Nasr_(Cairo)
# 20      98101.0  Mortuary_Temple_of_Seti_I_in_Qurna
# 36      64325.0               Great_Pyramid_of_Giza
# 81     170471.0                  Umm_Kulthum_Museum
# 85      34170.0                      Wadi_el-Raiyan

# %%
egypt['name'].value_counts().head(10).plot(kind = 'bar', title = "Occurance in Dataset")
# Out:
# <Axes: title={'center': 'Occurance in Dataset'}, xlabel='name'>
